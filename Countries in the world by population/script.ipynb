# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from datetime import datetime
import warnings
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://www.worldometers.info/world-population/population-by-country/"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
table = soup.find('table', {'id': 'example2'})
rows = table.tbody.find_all('tr')

population_result = []
for row in rows:
    columns = row.find_all('td')
    country = columns[1].a.text
    population = columns[2].text
    yearly_change = columns[3].text
    net_change = columns[4].text
    density = columns[5].text
    land_area = columns[6].text
    migrants = columns[7].text
    fert_rate = columns[8].text
    med_age = columns[9].text
    urban_pop = columns[10].text
    world_share = columns[11].text
    
    temporary_data = {'Country': country,
                      'Population': population,
                      'Yearly Change': yearly_change,
                      'World Share': world_share, 
                      'net change': net_change, 
                      'density': density, 
                      'land area': land_area, 
                      'migrants': migrants, 
                      'fert rate': fert_rate,
                      'med age': med_age, 
                      'urban pop': urban_pop, 
                      'world share': world_share, 
                      }
    population_result.append(temporary_data)

df_data = pd.DataFrame(population_result)
df_data.head(10)
# Out:
#          Country     Population Yearly Change World Share  net change density  \
# 0          China  1,439,323,776        0.39 %     18.47 %   5,540,090     153
# 1          India  1,380,004,385        0.99 %     17.70 %  13,586,631     464
# 2  United States    331,002,651        0.59 %      4.25 %   1,937,734      36
# 3      Indonesia    273,523,615        1.07 %      3.51 %   2,898,047     151
# 4       Pakistan    220,892,340        2.00 %      2.83 %   4,327,022     287
# 5         Brazil    212,559,417        0.72 %      2.73 %   1,509,890      25
# 6        Nigeria    206,139,589        2.58 %      2.64 %   5,175,990     226
# 7     Bangladesh    164,689,383        1.01 %      2.11 %   1,643,222   1,265
# 8         Russia    145,934,462        0.04 %      1.87 %      62,206       9
# 9         Mexico    128,932,753        1.06 %      1.65 %   1,357,224      66
#
#     land area  migrants fert rate med age urban pop world share
# ...

# %%
df_data.to_csv('population_data.csv')

# %%
##### for multiple pages #####

import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.worldometers.info/world-population/population-by-country/"
page_number = 1
page_limit = 5  # limit to 5 pages for example purposes only

population_result = []

while page_number <= page_limit:
    page_url = url + f"page={page_number}"
    response = requests.get(page_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', {'id': 'example2'})
    rows = table.tbody.find_all('tr')
    
    for row in rows:
        columns = row.find_all('td')
        country = columns[1].a.text
        population = columns[2].text
        yearly_change = columns[3].text
        net_change = columns[4].text
        density = columns[5].text
        land_area = columns[6].text
        migrants = columns[7].text
        fert_rate = columns[8].text
        med_age = columns[9].text
        urban_pop = columns[10].text
        world_share = columns[11].text
        
        population_data = {
            'country': country,
            'population': population,
            'yearly_change': yearly_change,
            'net_change': net_change,
            'density': density,
            'land_area': land_area,
            'migrants': migrants,
            'fert_rate': fert_rate,
            'med_age': med_age,
            'urban_pop': urban_pop,
            'world_share': world_share
        }
        
        population_result.append(population_data)
    
    page_number += 1
    
df = pd.DataFrame(population_result)
print(df)
