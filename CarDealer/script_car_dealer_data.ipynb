# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 

website = 'https://www.cars.com/shopping/results/?stock_type=cpo&makes%5B%5D=mercedes_benz&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

response = requests.get(website)

response.status_code

soup = BeautifulSoup(response.content, 'html.parser')

results = soup.find_all('div', {'class' : 'vehicle-card'})

len(results)

results[0].find('h2').get_text()

results[0].find('div', {'class':'mileage'}).get_text()

results[0].find('div', {'class':'dealer-name'}).get_text().strip()

results[0].find('span', {'class':'sds-rating__count'}).get_text()

results[0].find('span', {'class':'sds-rating__link'}).get_text()

results[0].find('span', {'class':'primary-price'}).get_text()

name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    try:
        name.append(result.find('h2').get_text()) 
    except:
        name.append('n/a')
    
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('n/a')
    
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')
        
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')
    
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')
    
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')


car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})


car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))
car_dealer
# Out:
#                                           Name     Mileage  \
# 0       2020 Mercedes-Benz CLA 250 Base 4MATIC  28,744 mi.
# 1           2019 Mercedes-Benz AMG SLC 43 Base  14,983 mi.
# 2            2018 Mercedes-Benz AMG SL 63 Base  19,480 mi.
# 3      2019 Mercedes-Benz AMG E 53 Base 4MATIC  23,163 mi.
# 4   2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe  42,022 mi.
# 5         2019 Mercedes-Benz AMG E 63 S 4MATIC  17,831 mi.
# 6              2022 Mercedes-Benz GLE 350 Base  17,488 mi.
# 7      2023 Mercedes-Benz E-Class E 450 4MATIC   6,521 mi.
# 8      2021 Mercedes-Benz E-Class E 450 4MATIC  12,477 mi.
# 9           2021 Mercedes-Benz AMG GLE 53 Base  33,578 mi.
# 10            2019 Mercedes-Benz S-Class S 560  49,332 mi.
# 11            2017 Mercedes-Benz S-Class S 550  26,032 mi.
# 12  2021 Mercedes-Benz AMG GLC 43 4MATIC Coupe  18,852 mi.
# 13      2020 Mercedes-Benz GLS 450 Base 4MATIC  43,940 mi.
# 14             2023 Mercedes-Benz GLA 250 Base   3,929 mi.
# 15            2021 Mercedes-Benz E-Class E 350  27,839 mi.
# 16  2019 Mercedes-Benz AMG GLE 43 4MATIC Coupe  28,450 mi.
# 17     2021 Mercedes-Benz E-Class E 450 4MATIC   8,173 mi.
# 18       2021 Mercedes-Benz GLE 450 AWD 4MATIC  16,210 mi.
# 19          2021 Mercedes-Benz AMG GLE 53 Base  24,253 mi.
# 20      2018 Mercedes-Benz GLA 250 Base 4MATIC  24,225 mi.
#
#                             Dealer Name Rating Review Count    Price
# 0             Mercedes-Benz of Lynnwood    4.4         130   $35,995
# 1            Mercedes-Benz Of Rochester    4.8         183   $50,974
# 2                    W.I. Simonson Inc.    4.6         889   $88,496
# 3        Mercedes-Benz of State College    n/a           2   $61,795
# 4       Mercedes-Benz of Goldens Bridge    4.4         236   $55,392
# 5     Baker Motor Company of Charleston    2.5         208   $86,998
# 6          Mercedes-Benz of St. Charles    4.7         589   $59,893
# 7             Mercedes-Benz of Westwood    2.4         441   $67,213
# 8                Benzel-Busch Motor Car    4.5       5,276   $76,532
# 9            Mercedes-Benz of Rochester    4.7         152   $76,995
# 10             Mercedes-Benz of Ontario    4.8       2,016   $55,480
# 11                      Star Motor Cars    3.7          63   $69,880
# 12          Mercedes-Benz of Wilmington    4.5       1,793   $62,900
# 13      Mercedes-Benz of Goldens Bridge    4.4         236   $57,791
# 14             Mercedes-Benz of Gilbert    3.8         350   $37,888
# 15  Fletcher Jones Motorcars of Fremont    4.7       1,220   $45,980
# 16        Mercedes-Benz of Walnut Creek    4.5       1,016   $53,986
# 17           Mercedes-Benz of Lancaster    4.8         172   $67,990
# 18            Volkswagen of Quad Cities    4.8         179   $64,300
# 19          Mercedes-Benz of Naperville    4.7         884   $71,200
# 20      Mercedes-Benz of Goldens Bridge    4.4         236   $29,900

# %% [markdown]
# ## Part 2 - Pagination

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range (1,11):
    
    website = 'https://www.cars.com/shopping/results/?page='+ str(i) +'&page_size=20&dealer_id=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=20&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip=' 
    
    response = requests.get(website)
    
    soup = BeautifulSoup(response.content, 'html.parser')
    
    results = soup.find_all('div', {'class' : 'vehicle-card'})
    
    for result in results:
    
        try:
            name.append(result.find('h2').get_text()) 
        except:
            name.append('n/a')

        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('n/a')

        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

        try:
            rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
        except:
            rating.append('n/a')

        try:
            review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
        except:
            review_count.append('n/a')

        try:
            price.append(result.find('span', {'class':'primary-price'}).get_text())
        except:
            price.append('n/a')

car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))
car_dealer.to_csv('car_dealer_data.csv')
